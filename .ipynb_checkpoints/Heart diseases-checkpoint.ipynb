# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"E:\ai ml notes sheriyans\Heart Diseases\data\Heart diseases dataset.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# # EDA

# %%
df.isnull().sum() # dataset is clean
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df[df.duplicated()] # no duplicate value in df
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %% [markdown]
# # changing data type

# %% [markdown]
# df.dtypes

# %%
df.head(3)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0

# %% [markdown]
# changing sex column data type object to int

# %%
df['Sex'] =  df['Sex'].map({'M':1,'F':0})

# %%
df.rename(columns = {'Sex':'is_male'} ,inplace=True)

# %% [markdown]
# changing sex column data type object to int

# %%
df['ExerciseAngina'].value_counts()
# Out:
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64

# %%
df['ExerciseAngina'] =  df['ExerciseAngina'].map({'Y':1,'N':0})

# %%
df.rename(columns = {'ExerciseAngina':'is_exerciseAngina'} ,inplace=True)

# %%
df.dtypes
# Out:
# Age                    int64
# is_male                int64
# ChestPainType         object
# RestingBP              int64
# Cholesterol            int64
# FastingBS              int64
# RestingECG            object
# MaxHR                  int64
# is_exerciseAngina      int64
# Oldpeak              float64
# ST_Slope              object
# HeartDisease           int64
# dtype: object

# %%
df.head(3)
# Out:
#    Age  is_male ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40        1           ATA        140          289          0     Normal
# 1   49        0           NAP        160          180          0     Normal
# 2   37        1           ATA        130          283          0         ST
#
#    MaxHR  is_exerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172                  0      0.0       Up             0
# 1    156                  0      1.0     Flat             1
# 2     98                  0      0.0       Up             0

# %%
sns.countplot(data = df,x = 'HeartDisease')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
col = ['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']

# %%
plt.figure(figsize = (9,9))

def plots(col,num):
    plt.subplot(3,3,num)
    sns.histplot(data = df,x = col,kde = True)
    


plots('Age',1)
plots('RestingBP',2)
plots('Cholesterol',3)
plots('MaxHR',4)
plots('Oldpeak',5)

plt.tight_layout()

# %% [markdown]
# # resting bp value can't be zero so replace the 0 with mean

# %%
df[df['RestingBP'] == 0]
# Out:
#      Age  is_male ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 449   55        1           NAP          0            0          0     Normal
#
#      MaxHR  is_exerciseAngina  Oldpeak ST_Slope  HeartDisease
# 449    155                  0      1.5     Flat             1

# %%
resting_bpmean = df.loc[df['RestingBP'] != 0,'RestingBP'].mean()
resting_bpmean = resting_bpmean.round(0)

# %% [markdown]
# # Cholesterol value can't be zero so replace 0 with the mean

# %%
Cholesterol_mean = df.loc[df['Cholesterol'] != 0,'Cholesterol'].mean()
Cholesterol_mean = Cholesterol_mean.round(0)
Cholesterol_mean
# Out:
# 245.0

# %%
df['Cholesterol']  = df['Cholesterol'].replace(0,Cholesterol_mean)

# %%
sns.countplot(x = df['is_male'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='is_male', ylabel='count'>

# %%
sns.countplot(x = df['ChestPainType'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x = df['FastingBS'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
sns.boxplot(x = 'HeartDisease', y = 'Cholesterol',data = df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x='HeartDisease', y='Age', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Feature Engineering

# %%
df_encode = pd.get_dummies(df,drop_first=True)

# %%
df_encode.head()
# Out:
#    Age  is_male  RestingBP  Cholesterol  FastingBS  MaxHR  is_exerciseAngina  \
# 0   40        1        140          289          0    172                  0
# 1   49        0        160          180          0    156                  0
# 2   37        1        130          283          0     98                  0
# 3   48        0        138          214          0    108                  1
# 4   54        1        150          195          0    122                  0
#
#    Oldpeak  HeartDisease  ChestPainType_ATA  ChestPainType_NAP  \
# 0      0.0             0               True              False
# 1      1.0             1              False               True
# 2      0.0             0               True              False
# 3      1.5             1              False              False
# 4      0.0             0              False               True
#
#    ChestPainType_TA  RestingECG_Normal  RestingECG_ST  ST_Slope_Flat  \
# ...

# %%
col = df_encode.columns
for i in col:
    if df_encode[i].dtype == bool:
        df_encode[i] = df_encode[i].astype(int)

# %%
from sklearn.preprocessing import StandardScaler
numerical_cols = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
scaler = StandardScaler()
df_encode[numerical_cols] = scaler.fit_transform(df_encode[numerical_cols])
df_encode.head()
# Out:
#         Age  is_male  RestingBP  Cholesterol  FastingBS     MaxHR  \
# 0 -1.433140        1   0.410909     0.831244          0  1.382928
# 1 -0.478484        0   1.491752    -1.214200          0  0.754157
# 2 -1.751359        1  -0.129513     0.718651          0 -1.525138
# 3 -0.584556        0   0.302825    -0.576172          0 -1.132156
# 4  0.051881        1   0.951331    -0.932717          0 -0.581981
#
#    is_exerciseAngina   Oldpeak  HeartDisease  ChestPainType_ATA  \
# 0                  0 -0.832432             0                  1
# 1                  0  0.105664             1                  0
# 2                  0 -0.832432             0                  1
# 3                  1  0.574711             1                  0
# 4                  0 -0.832432             0                  0
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_Normal  RestingECG_ST  \
# 0                  0                 0                  1              0
# ...

# %% [markdown]
# dataset is ready to build ml model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
X = df_encode.drop(columns = ['HeartDisease'])

# %%
y = df_encode['HeartDisease']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
models = {
    'KNN':KNeighborsClassifier(),
    'Logistic regression': LogisticRegression(),
    'navie bayes': GaussianNB(),
    'decision tree' : DecisionTreeClassifier(),
    'svm': SVC()
}

# %%
result = []

# %%
for name, model in models.items():
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)
    result.append(
        {'model':name,
         'accuracy': round(acc,4),
        'f1_score': round(f1,4),
        }
    )

# %%
result
# Out:
# [{'model': 'KNN', 'accuracy': 0.8548, 'f1_score': 0.875},
#  {'model': 'Logistic regression', 'accuracy': 0.8647, 'f1_score': 0.8805},
#  {'model': 'navie bayes', 'accuracy': 0.8548, 'f1_score': 0.8706},
#  {'model': 'decision tree', 'accuracy': 0.7855, 'f1_score': 0.8148},
#  {'model': 'svm', 'accuracy': 0.8548, 'f1_score': 0.875}]

# %%
import joblib

# %%
joblib.dump(models['Logistic regression'],'logistic_regression.pkl')
# Out:
# ['logistic_regression.pkl']

# %%
joblib.dump(scaler,'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
joblib.dump(X_train.columns.tolist(),'columns.pkl')
# Out:
# ['columns.pkl']
